# %%
# -----------------------------------------
# WHILE LOOP
# Count from 1 up to the user's number
# but stop early at 5
# +1
# -----------------------------------------

count = 1

while count <= number and count <= 5:
    print(count)
    count += 1   # increase count by 1 each loop



print()

# -----------------------------------------
# WHILE LOOP
# Count from 1 up to the user's number
# but stop early at 10
# +2
# -----------------------------------------

count = 1

while count <= number and count <= 10:
    print(count)
    count += 2   # increase count by 2 each loop
# Out:
# 1
# 2
# 3
# 4
# 5
#
# 1
# 3
# 5
# 7
# 9
